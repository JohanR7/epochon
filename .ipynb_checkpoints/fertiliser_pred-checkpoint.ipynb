# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
import pickle
import os
import datetime

# 1. Load Dataset
df = pd.read_csv('/Users/amanbacker/Desktop/hackathon/data/Fertilizer Prediction 1.csv')

# 2. Separate Features and Labels
features = df[['Temparature', 'Humidity ', 'Moisture', 'Nitrogen', 'Potassium', 'Phosphorous']]
fertilizer_labels = df['Fertilizer Name']

# 3. Encode Labels
fertilizer_encoder = LabelEncoder()
fertilizer_labels = fertilizer_encoder.fit_transform(fertilizer_labels)

# Save encoders for later use
os.makedirs('/Users/amanbacker/Desktop/hackathon/model/pkl_files/', exist_ok=True)
with open("/Users/amanbacker/Desktop/hackathon/model/pkl_files/fertilizer_encoder.pkl", "wb") as file:
    pickle.dump(fertilizer_encoder, file)

# 4. Normalize Features
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Save the scaler for later use
os.makedirs('/Users/amanbacker/Desktop/hackathon/model/normalization1/', exist_ok=True)
np.savez("/Users/amanbacker/Desktop/hackathon/model/normalization1/normalization1.npz", mean=scaler.mean_, std=np.sqrt(scaler.var_))

# 5. Split the Data into Training and Validation Sets
X_train, X_val, y_train_fertilizer, y_val_fertilizer = train_test_split(features_scaled, fertilizer_labels, test_size=0.2, random_state=42)

# 6. Define and Compile the Fertilizer Model
fertilizer_model = Sequential([
    Dense(128, activation='relu', input_shape=(features_scaled.shape[1],)),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dense(len(np.unique(fertilizer_labels)), activation='softmax')  # Output layer for Fertilizer
])
fertilizer_model.compile(optimizer=Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# 7. Train the Fertilizer Model
EPOCHS = 50
fertilizer_history = fertilizer_model.fit(X_train, y_train_fertilizer, validation_data=(X_val, y_val_fertilizer), epochs=EPOCHS, batch_size=32, verbose=2)

# 8. Save the Trained Fertilizer Model
os.makedirs('/Users/amanbacker/Desktop/hackathon/model/', exist_ok=True)
fertilizer_model_name = str(datetime.datetime.now()).replace(' ', '-').replace(':', '-').replace('.', '-') + '-fertilizer.h5'
fertilizer_model.save(f'/Users/amanbacker/Desktop/hackathon/model/{fertilizer_model_name}')

# 9. Plot the Training and Validation Loss for Fertilizer Model
import matplotlib.pyplot as plt
plt.plot(fertilizer_history.history['loss'], label='Train Loss')
plt.plot(fertilizer_history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Fertilizer Model - Loss')
plt.show()

# 10. Evaluate the Fertilizer Model
fertilizer_train_loss, fertilizer_train_acc = fertilizer_model.evaluate(X_train, y_train_fertilizer, verbose=0)
fertilizer_val_loss, fertilizer_val_acc = fertilizer_model.evaluate(X_val, y_val_fertilizer, verbose=0)

print(f"Fertilizer Model Accuracy on Training Set: {fertilizer_train_acc * 100:.2f}%")
print(f"Fertilizer Model Accuracy on Validation Set: {fertilizer_val_acc * 100:.2f}%")
# Out:
# Epoch 1/50
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 3/3 - 0s - 108ms/step - accuracy: 0.1266 - loss: 1.9852 - val_accuracy: 0.0000e+00 - val_loss: 2.0138
# Epoch 2/50
# 3/3 - 0s - 6ms/step - accuracy: 0.1772 - loss: 1.9057 - val_accuracy: 0.0500 - val_loss: 1.9286
# Epoch 3/50
# 3/3 - 0s - 6ms/step - accuracy: 0.2785 - loss: 1.8290 - val_accuracy: 0.2500 - val_loss: 1.8538
# Epoch 4/50
# 3/3 - 0s - 7ms/step - accuracy: 0.4557 - loss: 1.7398 - val_accuracy: 0.4000 - val_loss: 1.7805
# Epoch 5/50
# 3/3 - 0s - 6ms/step - accuracy: 0.6329 - loss: 1.6301 - val_accuracy: 0.4500 - val_loss: 1.7088
# Epoch 6/50
# 3/3 - 0s - 6ms/step - accuracy: 0.5949 - loss: 1.5881 - val_accuracy: 0.4500 - val_loss: 1.6361
# Epoch 7/50
# 3/3 - 0s - 7ms/step - accuracy: 0.6203 - loss: 1.5403 - val_accuracy: 0.4500 - val_loss: 1.5650
# Epoch 8/50
# 3/3 - 0s - 7ms/step - accuracy: 0.6835 - loss: 1.4383 - val_accuracy: 0.5500 - val_loss: 1.4986
# Epoch 9/50
# 3/3 - 0s - 6ms/step - accuracy: 0.7089 - loss: 1.3700 - val_accuracy: 0.6500 - val_loss: 1.4332
# Epoch 10/50
# 3/3 - 0s - 7ms/step - accuracy: 0.7342 - loss: 1.3257 - val_accuracy: 0.6500 - val_loss: 1.3706
# Epoch 11/50
# 3/3 - 0s - 6ms/step - accuracy: 0.7089 - loss: 1.2496 - val_accuracy: 0.6500 - val_loss: 1.3113
# Epoch 12/50
# 3/3 - 0s - 6ms/step - accuracy: 0.7848 - loss: 1.1982 - val_accuracy: 0.6500 - val_loss: 1.2590
# Epoch 13/50
# 3/3 - 0s - 7ms/step - accuracy: 0.7342 - loss: 1.1309 - val_accuracy: 0.6500 - val_loss: 1.2083
# Epoch 14/50
# 3/3 - 0s - 6ms/step - accuracy: 0.6962 - loss: 1.0862 - val_accuracy: 0.6500 - val_loss: 1.1542
# Epoch 15/50
# 3/3 - 0s - 6ms/step - accuracy: 0.7848 - loss: 0.9927 - val_accuracy: 0.6500 - val_loss: 1.0990
# Epoch 16/50
# 3/3 - 0s - 7ms/step - accuracy: 0.8228 - loss: 0.9564 - val_accuracy: 0.6500 - val_loss: 1.0450
# Epoch 17/50
# 3/3 - 0s - 6ms/step - accuracy: 0.8354 - loss: 0.8773 - val_accuracy: 0.6500 - val_loss: 0.9979
# Epoch 18/50
# 3/3 - 0s - 6ms/step - accuracy: 0.8861 - loss: 0.8356 - val_accuracy: 0.6500 - val_loss: 0.9489
# Epoch 19/50
# 3/3 - 0s - 6ms/step - accuracy: 0.8734 - loss: 0.7871 - val_accuracy: 0.6500 - val_loss: 0.9061
# Epoch 20/50
# 3/3 - 0s - 6ms/step - accuracy: 0.9114 - loss: 0.7105 - val_accuracy: 0.6500 - val_loss: 0.8650
# Epoch 21/50
# 3/3 - 0s - 6ms/step - accuracy: 0.8861 - loss: 0.7425 - val_accuracy: 0.6500 - val_loss: 0.8270
# Epoch 22/50
# 3/3 - 0s - 6ms/step - accuracy: 0.9114 - loss: 0.6205 - val_accuracy: 0.7500 - val_loss: 0.7928
# Epoch 23/50
# 3/3 - 0s - 6ms/step - accuracy: 0.9367 - loss: 0.6289 - val_accuracy: 0.7500 - val_loss: 0.7541
# Epoch 24/50
# 3/3 - 0s - 6ms/step - accuracy: 0.9241 - loss: 0.5948 - val_accuracy: 0.7500 - val_loss: 0.7159
# Epoch 25/50
# 3/3 - 0s - 23ms/step - accuracy: 0.9367 - loss: 0.5254 - val_accuracy: 0.8500 - val_loss: 0.6793
# Epoch 26/50
# 3/3 - 0s - 6ms/step - accuracy: 0.9620 - loss: 0.5003 - val_accuracy: 0.8500 - val_loss: 0.6476
# Epoch 27/50
# 3/3 - 0s - 6ms/step - accuracy: 0.9620 - loss: 0.4470 - val_accuracy: 0.8500 - val_loss: 0.6140
# Epoch 28/50
# 3/3 - 0s - 6ms/step - accuracy: 0.9367 - loss: 0.4390 - val_accuracy: 0.8500 - val_loss: 0.5811
# Epoch 29/50
# 3/3 - 0s - 6ms/step - accuracy: 0.9747 - loss: 0.3760 - val_accuracy: 0.8500 - val_loss: 0.5538
# Epoch 30/50
# 3/3 - 0s - 6ms/step - accuracy: 0.9494 - loss: 0.3857 - val_accuracy: 0.8500 - val_loss: 0.5261
# Epoch 31/50
# 3/3 - 0s - 6ms/step - accuracy: 0.9747 - loss: 0.3260 - val_accuracy: 0.8500 - val_loss: 0.4980
# Epoch 32/50
# 3/3 - 0s - 6ms/step - accuracy: 0.9873 - loss: 0.3291 - val_accuracy: 0.8500 - val_loss: 0.4680
# Epoch 33/50
# 3/3 - 0s - 6ms/step - accuracy: 0.9747 - loss: 0.3100 - val_accuracy: 0.8500 - val_loss: 0.4337
# Epoch 34/50
# 3/3 - 0s - 7ms/step - accuracy: 0.9620 - loss: 0.2940 - val_accuracy: 0.8500 - val_loss: 0.4078
# Epoch 35/50
# 3/3 - 0s - 7ms/step - accuracy: 0.9620 - loss: 0.2592 - val_accuracy: 0.8500 - val_loss: 0.3824
# Epoch 36/50
# 3/3 - 0s - 7ms/step - accuracy: 0.9873 - loss: 0.2497 - val_accuracy: 0.8500 - val_loss: 0.3622
# Epoch 37/50
# 3/3 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.2292 - val_accuracy: 0.9000 - val_loss: 0.3461
# Epoch 38/50
# 3/3 - 0s - 6ms/step - accuracy: 0.9620 - loss: 0.2520 - val_accuracy: 0.9000 - val_loss: 0.3292
# Epoch 39/50
# 3/3 - 0s - 6ms/step - accuracy: 0.9747 - loss: 0.2222 - val_accuracy: 0.9000 - val_loss: 0.3162
# Epoch 40/50
# 3/3 - 0s - 6ms/step - accuracy: 0.9747 - loss: 0.2127 - val_accuracy: 0.9000 - val_loss: 0.2985
# Epoch 41/50
# 3/3 - 0s - 6ms/step - accuracy: 0.9873 - loss: 0.1962 - val_accuracy: 0.9000 - val_loss: 0.2829
# Epoch 42/50
# 3/3 - 0s - 6ms/step - accuracy: 0.9620 - loss: 0.1769 - val_accuracy: 0.9000 - val_loss: 0.2677
# Epoch 43/50
# 3/3 - 0s - 6ms/step - accuracy: 0.9747 - loss: 0.1848 - val_accuracy: 0.9000 - val_loss: 0.2538
# Epoch 44/50
# 3/3 - 0s - 6ms/step - accuracy: 0.9873 - loss: 0.1606 - val_accuracy: 0.9000 - val_loss: 0.2427
# Epoch 45/50
# 3/3 - 0s - 6ms/step - accuracy: 0.9620 - loss: 0.1683 - val_accuracy: 0.9000 - val_loss: 0.2308
# Epoch 46/50
# 3/3 - 0s - 6ms/step - accuracy: 0.9873 - loss: 0.1427 - val_accuracy: 0.9000 - val_loss: 0.2229
# Epoch 47/50
# 3/3 - 0s - 6ms/step - accuracy: 0.9873 - loss: 0.1321 - val_accuracy: 0.9000 - val_loss: 0.2132
# Epoch 48/50
# 3/3 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1425 - val_accuracy: 0.9500 - val_loss: 0.2030
# Epoch 49/50
# 3/3 - 0s - 6ms/step - accuracy: 0.9873 - loss: 0.1448 - val_accuracy: 0.9000 - val_loss: 0.1963
# Epoch 50/50
# 3/3 - 0s - 6ms/step - accuracy: 0.9873 - loss: 0.1264 - val_accuracy: 0.9000 - val_loss: 0.1946
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Fertilizer Model Accuracy on Training Set: 100.00%
# Fertilizer Model Accuracy on Validation Set: 90.00%

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tensorflow.keras.models import load_model
import pickle

# Load the saved encoder and scaler
with open('/Users/amanbacker/Desktop/hackathon/model/pkl_files/fertilizer_encoder.pkl', 'rb') as file:
    fertilizer_encoder = pickle.load(file)

scaler_data = np.load('/Users/amanbacker/Desktop/hackathon/model/normalization1/normalization1.npz')
scaler_mean = scaler_data['mean']
scaler_std = np.sqrt(scaler_data['std'])
scaler = StandardScaler()
scaler.mean_ = scaler_mean
scaler.scale_ = scaler_std

# Load the trained fertilizer model
fertilizer_model = load_model('/Users/amanbacker/Desktop/hackathon/model/2024-11-30-02-26-32-134992-fertilizer.h5')  # Replace with your actual saved model path

# Function to make a prediction
def predict_fertilizer(nitrogen, phosphorus, potassium, humidity, temperature):
    # Prepare the input features in the same way as the training data
    input_data = np.array([[nitrogen, phosphorus, potassium, humidity, temperature]])
    
    # Scale the input data using the same scaler used for training
    input_scaled = scaler.transform(input_data)
    
    # Get the model's prediction
    prediction = fertilizer_model.predict(input_scaled)
    
    # Decode the prediction back to the fertilizer name
    predicted_fertilizer_index = np.argmax(prediction, axis=1)[0]
    predicted_fertilizer = fertilizer_encoder.inverse_transform([predicted_fertilizer_index])[0]
    
    return predicted_fertilizer

# Example usage: Get fertilizer for given inputs
nitrogen = float(input("Enter Nitrogen level: "))
phosphorus = float(input("Enter Phosphorus level: "))
potassium = float(input("Enter Potassium level: "))
humidity = float(input("Enter Humidity level: "))
temperature = float(input("Enter Temperature: "))

predicted_fertilizer = predict_fertilizer(nitrogen, phosphorus, potassium, humidity, temperature)
print(f"The recommended fertilizer is: {predicted_fertilizer}")
